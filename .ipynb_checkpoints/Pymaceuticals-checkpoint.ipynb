# %%
#Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# %%
#Combine the data
combined_results = study_results.merge(mouse_metadata, on="Mouse ID")
combined_results.head(10)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
# 5     b128         25           43.262145                 1    Capomulin
# 6     b128         30           40.605335                 1    Capomulin
# 7     b128         35           37.967644                 1    Capomulin
# 8     b128         40           38.379726                 2    Capomulin
# 9     b128         45           38.982878                 2    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22
# 5  Female           9          22
# 6  Female           9          22
# 7  Female           9          22
# 8  Female           9          22
# 9  Female           9          22

# %%
#Removing dead mice
ids = combined_results["Mouse ID"].unique()
living_mice = combined_results.loc[combined_results["Timepoint"] == 45]

#Start and End only
start_df = combined_results.loc[combined_results["Timepoint"] == 0]
start_df.head()
end_df = combined_results.loc[combined_results["Timepoint"] == 45]
end_df.head()
start_end_df = pd.merge(start_df, end_df, on="Mouse ID", suffixes=(" Start", " End"))
start_end_df = start_end_df.drop(["Drug Regimen End", "Sex End", "Age_months End"], axis=1)
start_end_df = start_end_df.rename({"Drug Regimen Start":"Drug Regimen", "Sex Start":"Sex", "Age_months Start":"Age_months"},
                                   axis=1)
start_end_df.head()
# Out:
#   Mouse ID  Timepoint Start  Tumor Volume (mm3) Start  Metastatic Sites Start  \
# 0     b128                0                      45.0                       0
# 1     h246                0                      45.0                       0
# 2     p189                0                      45.0                       0
# 3     b559                0                      45.0                       0
# 4     y260                0                      45.0                       0
#
#   Drug Regimen     Sex  Age_months  Weight (g) Start  Timepoint End  \
# 0    Capomulin  Female           9                22             45
# 1     Ketapril    Male          13                30             45
# 2     Ketapril    Male           8                28             45
# 3     Naftisol    Male          20                26             45
# 4     Ketapril  Female           7                25             45
#
#    Tumor Volume (mm3) End  Metastatic Sites End  Weight (g) End
# 0               38.982878                     2              22
# 1               74.104086                     2              30
# 2               75.294936                     4              28
# 3               73.051363                     1              26
# 4               62.909441                     4              25

# %%
#Group data by every timepoint per regiment
grouped_regiment = start_end_df.groupby(["Drug Regimen"])
grouped_regiment.count().head()
# Out:
#               Mouse ID  Timepoint Start  Tumor Volume (mm3) Start  \
# Drug Regimen
# Capomulin           21               21                        21
# Ceftamin            13               13                        13
# Infubinol            9                9                         9
# Ketapril            11               11                        11
# Naftisol            13               13                        13
#
#               Metastatic Sites Start  Sex  Age_months  Weight (g) Start  \
# Drug Regimen
# Capomulin                         21   21          21                21
# Ceftamin                          13   13          13                13
# Infubinol                          9    9           9                 9
# Ketapril                          11   11          11                11
# Naftisol                          13   13          13                13
#
#               Timepoint End  Tumor Volume (mm3) End  Metastatic Sites End  \
# Drug Regimen
# Capomulin                21                      21                    21
# Ceftamin                 13                      13                    13
# Infubinol                 9                       9                     9
# Ketapril                 11                      11                    11
# Naftisol                 13                      13                    13
#
#               Weight (g) End
# Drug Regimen
# Capomulin                 21
# Ceftamin                  13
# Infubinol                  9
# Ketapril                  11
# Naftisol                  13

# %%
#Set up a dataframe holding stats for each timepoint per regiment
tumor_med = grouped_regiment["Tumor Volume (mm3)"].median()
tumor_avg = grouped_regiment["Tumor Volume (mm3)"].mean()
tumor_sem = grouped_regiment["Tumor Volume (mm3)"].sem()
tumor_std = grouped_regiment["Tumor Volume (mm3)"].std()
tumor_var = grouped_regiment["Tumor Volume (mm3)"].var()
grouped_regiment_df = pd.DataFrame({"Median":tumor_med, "Average":tumor_avg, "SEM":tumor_sem, "Stand. Dev.":tumor_std, 
                                    "Variance":tumor_var})

#Define function to create stat summary for each regimen
def regimen_stat(regimen):
    return grouped_regiment_df.loc[regimen, :]

#For loop to print all the stat sums for all the regimens
regimens = combined_results["Drug Regimen"].unique()
for regimen in regimens:
    print(regimen)
    print(regimen_stat(str(regimen)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-a4df5adeeb08> in <module>
#       1 #Set up a dataframe holding stats for each timepoint per regiment
# ----> 2 tumor_med = grouped_regiment["Tumor Volume (mm3)"].median()
#       3 tumor_avg = grouped_regiment["Tumor Volume (mm3)"].mean()
#       4 tumor_sem = grouped_regiment["Tumor Volume (mm3)"].sem()
#       5 tumor_std = grouped_regiment["Tumor Volume (mm3)"].std()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1611                 stacklevel=2,
#    1612             )
# -> 1613         return super().__getitem__(key)
#    1614
#    1615     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     237         else:
#     238             if key not in self.obj:
# --> 239                 raise KeyError(f"Column not found: {key}")
#     240             return self._gotitem(key, ndim=1)
#     241
#
# KeyError: 'Column not found: Tumor Volume (mm3)'
